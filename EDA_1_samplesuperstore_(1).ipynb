# %% [markdown]
# IMPORT DIFFERENT LIBERARIES For data analysis

# %%
import pandas as pd  #for cleaning data
import numpy as np   #for mathematical calculation
import matplotlib.pyplot as plt  #for data visualization
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ## LOAD DATASET

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Data description

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.sample(5)
# Out:
#            Ship Mode      Segment        Country         City           State  \
# 7533  Standard Class     Consumer  United States   Greenville  North Carolina
# 8126  Standard Class     Consumer  United States      Houston           Texas
# 7449    Second Class  Home Office  United States      Houston           Texas
# 3546     First Class  Home Office  United States     Richmond        Kentucky
# 3448  Standard Class     Consumer  United States  Los Angeles      California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 7533        27834    South        Furniture       Chairs  196.784         2
# 8126        77070  Central       Technology  Accessories   18.528         2
# 7449        77036  Central  Office Supplies          Art    9.912         3
# 3546        40475    South  Office Supplies      Storage  105.980         7
# 3448        90049     West  Office Supplies      Binders   27.264         2
#
#       Discount   Profit
# 7533       0.2 -22.1382
# 8126       0.2   4.4004
# 7449       0.2   3.2214
# 3546       0.0   4.2392
# 3448       0.2   8.8608

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.duplicated().sum() #find duplicates
# Out:
# np.int64(17)

# %%
df.drop_duplicates(inplace = True) ## drop duplicates for better EDA

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ##We have learned so far that features have three types - categorical , numerical,mixed

# %% [markdown]
# we are having 13 features
# Ship Mode,	Segment,	Country,	City,	State,	Postal Code,	Region,	Category,	Sub-Category,	Sales	Quantity,	Discount,	Profit

# %% [markdown]
# steps to perform eda
#
#
# 1.   lebeling
# 2.   Univariate Analysis
# 3.   Bi-Variate analysis
# 4.   Multivariate Analysis
# 5.   Conclusions

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %% [markdown]
# ## Numerical Features

# %% [markdown]
# ### Sales

# %%
df['Sales'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df['Sales'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# too many outliers

# %%
df['Sales'].plot(kind='hist',bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Sales'].skew()
# Out:
# np.float64(12.97275234181623)

# %% [markdown]
# we can see that this data of Sales is highly positive skewed

# %% [markdown]
# ###profit

# %%
df['Profit'].describe()
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
df['Profit'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Profit'].plot(kind ='hist',bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Profit'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Profit'].skew()
# Out:
# np.float64(7.561431562468343)

# %% [markdown]
# Right skewed

# %% [markdown]
# ###Discount

# %%
df['Discount'].describe()
# Out:
# count    9994.000000
# mean        0.156203
# std         0.206452
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64

# %%
df['Discount'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Discount'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Discount'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Discount'].skew()
# Out:
# np.float64(1.6842947474238648)

# %% [markdown]
# kind of normal

# %% [markdown]
# ###Quantity

# %%
df['Quantity'].describe()
# Out:
# count    9994.000000
# mean        3.789574
# std         2.225110
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %%
df['Quantity'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Quantity'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Quantity'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Quantity'].skew()
# Out:
# np.float64(1.2785447527223421)

# %% [markdown]
# slightly possitive skewed

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ### Ship mode

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Ship Mode",data=df)
plt.show()

# %%
df['Ship Mode'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Univariate analysis for categorical column

# %%
df["Region"].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df["Category"].value_counts().plot(kind='pie',autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Subcategory analysis

# %%
df["Sub-Category"].value_counts()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(y="Sub-Category",data=df,palette="hsv")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12216\3265906160.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="Sub-Category",data=df,palette="hsv")

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %%
# corelation

# %%
corr =df[["Postal Code","Sales","Quantity","Discount","Profit"]].corr()
sns.heatmap(corr,annot=True,cmap="summer")
# Out:
# <Axes: >

# %% [markdown]
# # conclusions after multivariate correlation
#
#
# *    discount and sales are negatively correlated
# *   quantity and profit are moderatively correlated
# *   sales and profit are positively correlated
# *   profit and discount negatively correlated

# %% [markdown]
# # Scatter plot between sales and profit

# %%
sns.scatterplot(data=df,x="Sales",y="Profit",hue="Ship Mode")
plt.show()

# %% [markdown]
# * profit and Quantity Analysis
# * profit and discount

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 10))

# First subplot: Profit & Quantity Relation based on Sub-Category
df.groupby('Sub-Category')[['Profit', 'Quantity']].agg('sum').plot(kind='bar', ax=axes[0])
axes[0].set_title('Profit & Quantity Relation based on Sub-Category')

# Second subplot: Profit & Discount Relation based on Sub-Category
df.groupby('Sub-Category')[['Profit', 'Discount']].agg('sum').plot(kind='bar', ax=axes[1])
axes[1].set_title('Profit & Discount Relation based on Sub-Category')

# Rotate x-axis labels for better readability
axes[0].tick_params(axis='x', rotation=90)
axes[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# * Profit and Region Analysis

# %%
sns.barplot(x='Region',y='Profit',data=df,palette="Set2")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12216\3524815313.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region',y='Profit',data=df,palette="Set2")

# %% [markdown]
# * City and Profit analysis

# %%
sns.barplot(y='City',x='Profit',data=df[: 30],palette="Set2")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_12216\1334881700.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y='City',x='Profit',data=df[: 30],palette="Set2")

# %% [markdown]
# * Quantiy and region Analysis

# %%
plt.figure(figsize=(10,6))

sns.countplot(x="Quantity",data=df,hue="Region",palette="hot")
plt.show()

# %%
# Creating the figure and subplots
fig = plt.figure(figsize=(16, 8))
fig.suptitle("Sales with different shipping modes and Segments", fontsize=16)

# First subplot: Bar plot of Sales by Ship Mode
ax1 = fig.add_subplot(221)
sns.barplot(x=df['Ship Mode'], y=df['Sales'], ax=ax1, dodge=False)
ax1.set_title('Sales by Ship Mode')

# Second subplot: Line plot of Sales by Ship Mode
ax2 = fig.add_subplot(222)
sns.lineplot(x=df['Ship Mode'], y=df['Sales'], ax=ax2)
ax2.set_title('Sales by Ship Mode')

# Third subplot: Bar plot of Sales by Segment
ax3 = fig.add_subplot(223)
sns.barplot(x=df['Segment'], y=df['Sales'], ax=ax3)
ax3.set_title('Sales by Segment')

# Fourth subplot: Line plot of Sales by Segment
ax4 = fig.add_subplot(224)
sns.lineplot(x=df['Segment'], y=df['Sales'], ax=ax4)
ax4.set_title('Sales by Segment')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Conclusion**
# * Correlation Analysis: Profit & Sales, Quantity & Sales show positive relationships.
#
# * Discount Strategy: More discounts offered on Office Supplies & Furniture.
#
# * Central Region Strategy: Despite high discounts, low output in quantity. Optimize discount strategies.
#
# * Product Allocation: Shift quantity from Office Supplies to Furniture for better sales.
#
# * Demand Analysis: Most products in demand have quantities in the range 2-4.
#
# * Shipping Impact: Minimal impact of shipping mode on sales.
#
# * Focus Areas: Technology sub-category, Phones, and Chairs are high-selling and profitable.
#
# * Product Bundling: Bundle high-selling products with less profitable ones.
#
# * Loss-Making Products: Consider dropping or changing suppliers for products like Bookcases and Tables.
#
# * Customer Targeting: Focus on Consumer and Corporate segments, especially in top cities, with special promotions and bundles.
